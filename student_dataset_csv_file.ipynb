# %% [markdown]
# <a href="https://colab.research.google.com/github/krish04122005/krish_k412/blob/main/student_dataset_csv_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "sentimentdataset(1)(1).csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the data from "sentimentdataset(1)(1).csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from "sentimentdataset(1)(1).csv" into a pandas DataFrame and display the first few rows.

# %%
import pandas as pd

try:
    df = pd.read_csv('sentimentdataset(1)(1).csv')
    display(df.head())
except FileNotFoundError:
    print("Error: 'sentimentdataset(1)(1).csv' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    S.NO  Unnamed: 0                                               Text  \
# 0     1           0   Enjoying a beautiful day at the park!        ...
# 1     2           1   Traffic was terrible this morning.           ...
# 2     3           2   Just finished an amazing workout! 💪          ...
# 3     4           3   Excited about the upcoming weekend getaway!  ...
# 4     5           4   Trying out a new recipe for dinner tonight.  ...
#
#      Sentiment        Timestamp            User     Platform  \
# 0   Positive    1/15/2023 12:30   User123          Twitter
# 1   Negative     1/15/2023 8:45   CommuterX        Twitter
# 2   Positive    1/15/2023 15:45   FitnessFan      Instagram
# 3   Positive    1/15/2023 18:20   AdventureX       Facebook
# 4   Neutral     1/15/2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the dataset to understand its structure, identify the target variable, and check for missing values.

# %% [markdown]
# **Reasoning**:
# I need to explore the dataset's structure, identify the target variable, and check for missing values, unique values, and data types.  I can do this with `.shape`, `.info()`, `.describe()`, `.isnull().sum()`, and `.nunique()`.

# %%
# Examine the DataFrame's shape
print("DataFrame Shape:", df.shape)

# Check data types and missing values
print("\nDataFrame Info:")
df.info()

# Summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Identify the target variable (likely 'Sentiment')
target_variable = 'Sentiment'
print(f"\nTarget Variable: {target_variable}")

# Missing values
print("\nMissing Values per column:")
print(df.isnull().sum())

# Unique values
print("\nUnique Values per column:")
print(df.nunique())
# Out:
# DataFrame Shape: (100, 15)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.NO        100 non-null    int64
#  1   Unnamed: 0  100 non-null    int64
#  2   Text        100 non-null    object
#  3   Sentiment   100 non-null    object
#  4   Timestamp   100 non-null    object
#  5   User        100 non-null    object
#  6   Platform    100 non-null    object
#  7   Hashtags    100 non-null    object
#  8   Retweets    100 non-null    int64
#  9   Likes       100 non-null    int64
#  10  Country     100 non-null    object
#  11  Year        100 non-null    int64
#  12  Month       100 non-null    int64
#  13  Day         100 non-null    int64
#  14  Hour        100 non-null    int64
# dtypes: int64(8), object(7)
# memory usage: 11.8+ KB
#
# Summary Statistics:
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze the distribution of the target variable and explore potential correlations between features.

# %% [markdown]
# **Reasoning**:
# Analyze the distribution of the 'Sentiment' column, calculate basic statistics for numerical features grouped by sentiment, and investigate correlations between numerical features. Visualize these using appropriate plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sentiment distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Sentiment', data=df)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.show()

# Numerical features vs. Sentiment
numerical_features = ['Retweets', 'Likes']
plt.figure(figsize=(12, 6))
for i, feature in enumerate(numerical_features):
    plt.subplot(1, 2, i + 1)
    sns.boxplot(x='Sentiment', y=feature, data=df)
    plt.title(f'{feature} vs. Sentiment')
    plt.xlabel('Sentiment')
    plt.ylabel(feature)
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Correlation matrix
correlation_matrix = df[numerical_features].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# Grouped statistics
print(df.groupby('Sentiment')[numerical_features].agg(['mean', 'median', 'std']))
# Out:
#                 Retweets                        Likes
#                     mean median        std       mean median        std
# Sentiment
# Acceptance     15.000000   15.0   0.000000  30.000000   30.0   0.000000
# Admiration     20.000000   20.0   0.000000  40.000000   40.0   0.000000
# Adoration      22.000000   22.0   0.000000  45.000000   45.0   0.000000
# Affection      15.000000   15.0   0.000000  30.000000   30.0   0.000000
# Amusement      18.000000   18.0   0.000000  35.000000   35.0   0.000000
# Anger          20.000000   20.0   0.000000  40.000000   40.0   0.000000
# Anticipation   20.000000   20.0   0.000000  40.000000   40.0   0.000000
# Awe            22.000000   22.0   0.000000  45.000000   45.0   0.000000
# Bitter         18.000000   18.0   0.000000  35.000000   35.0   0.000000
# Calmness       15.000000   15.0   0.000000  30.000000   30.0   0.000000
# Confusion      25.000000   25.0   0.000000  50.000000   50.0   0.000000
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Create visualizations to better understand the data.

# %% [markdown]
# **Reasoning**:
# Create visualizations for the distribution of the target variable, relationships between numerical features and the target variable, and relationships between categorical features and the target variable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sentiment distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Sentiment', data=df)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.show()

# Numerical features vs. Sentiment
numerical_features = ['Retweets', 'Likes']
plt.figure(figsize=(12, 6))
for i, feature in enumerate(numerical_features):
    plt.subplot(1, 2, i + 1)
    sns.boxplot(x='Sentiment', y=feature, data=df)
    plt.title(f'{feature} vs. Sentiment')
    plt.xlabel('Sentiment')
    plt.ylabel(feature)
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Categorical features vs. Sentiment
categorical_features = ['Platform', 'Country']
plt.figure(figsize=(12, 6))
for i, feature in enumerate(categorical_features):
    plt.subplot(1, 2, i + 1)
    sns.countplot(x=feature, hue='Sentiment', data=df)
    plt.title(f'Sentiment Distribution by {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Q&A
# There were no explicit questions asked in the provided task. However, the analysis implicitly sought to understand the dataset's characteristics, including the distribution of sentiments, relationships between features and sentiment, and potential correlations between numerical features.
#
# ### Data Analysis Key Findings
# * The dataset contains 100 rows and 15 columns, with no missing values.
# * The target variable is 'Sentiment', which has 27 unique categories, suggesting a multi-class classification problem.
# * The 'Text', 'Timestamp', 'User', and 'S.NO' columns have 100 unique values each.
# * Visualizations revealed the distribution of sentiments and relationships between numerical features ('Retweets', 'Likes') and sentiment categories.  Boxplots showed potential differences in 'Retweets' and 'Likes' across different sentiments.
# * A correlation matrix showed the correlation between 'Retweets' and 'Likes'.  The analysis also explored the relationship between categorical features ('Platform', 'Country') and the target variable.
#
# ### Insights or Next Steps
# * Further investigation into the text data ('Text' column) using Natural Language Processing (NLP) techniques is warranted to understand the nuances of the sentiments expressed.
# * Explore more sophisticated statistical methods or machine learning models to predict sentiment based on the available features.
